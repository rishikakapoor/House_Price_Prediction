# %% [markdown]
# # Predicting House Price
# ## Exploratory Data Analysis

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Test and Train dataset

# %%
house_train_dataset= pd.read_csv("/Users/rishika/Desktop/data/train.csv")

# %%
house_train_dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
house_test_dataset= pd.read_csv("/Users/rishika/Desktop/data/test.csv")

# %%
house_test_dataset.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %% [markdown]
# ### Data Insights

# %%
house_train_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
nulls = house_train_dataset.isnull().sum()
nulls
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
#                  ...
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# ...

# %% [markdown]
# ## Target Variable

# %%
target_variable= house_train_dataset["SalePrice"]

# %%
plt.figure(figsize = (14, 6))
plt.subplot(1,2,1)
sns.boxplot(target_variable)
plt.subplot(1,2,2)
sns.distplot(target_variable, bins=20)
plt.show()

# %% [markdown]
# ### Transformaion to remove skewness

# %%
plt.figure(figsize = (14, 6))
plt.subplot(1,2,1)
sns.boxplot(np.log(target_variable))
plt.subplot(1,2,2)
sns.distplot(np.log(target_variable), bins=20)
plt.show()

# %% [markdown]
# ## Outliers
# There are many outliers, but none of them looks like corrupt data.
#
# It is better to keep these outliers

# %%
stats= target_variable.describe()
stats
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
IQR= stats['75%'] - stats['25%']
print(IQR)
Upper_bound= stats['75%'] + 1.5*IQR
lower_bound=stats['25%'] - 1.5*IQR

print('The upper bound and lower bound is {}, {}'.format(Upper_bound,lower_bound))
# Out:
# 84025.0
# The upper bound and lower bound is 340037.5, 3937.5

# %%
Uoutliers= house_train_dataset[house_train_dataset.SalePrice > 340037.5]
Uoutliers.head()
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 11    12          60       RL         85.0    11924   Pave   NaN      IR1
# 53    54          20       RL         68.0    50271   Pave   NaN      IR1
# 58    59          60       RL         66.0    13682   Pave   NaN      IR2
# 112  113          60       RL         77.0     9965   Pave   NaN      Reg
# 151  152          20       RL        107.0    13891   Pave   NaN      Reg
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 11          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 53          Low    AllPub  ...        0    NaN   NaN         NaN       0
# 58          HLS    AllPub  ...        0    NaN   NaN         NaN       0
# 112         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 151         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
print("The most frequent rating for the whole dataset is " +str(house_train_dataset.OverallQual.mode(0)))
print("The average rating for the whole dataset is " +str(house_train_dataset.OverallQual.mean()))
print("The most frequent rating for the High priced Houses is " +str(Uoutliers.OverallQual.mode(0)))
print("The average rating for the High priced Houses is " +str(Uoutliers.OverallQual.mean()))
# Out:
# The most frequent rating for the whole dataset is 0    5
# dtype: int64
# The average rating for the whole dataset is 6.0993150684931505
# The most frequent rating for the High priced Houses is 0    9
# dtype: int64
# The average rating for the High priced Houses is 8.754098360655737

# %% [markdown]
#  1. Most of the highly priced houses belong to 20 0r 60 MSSubClass.
#  2. All the highly priced houses have overallQuality more than 7, which makes it a fair dataset.

# %%
Loutliers= house_train_dataset[house_train_dataset.SalePrice < 3937.5]
Loutliers
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# ...

# %% [markdown]
# ## Analyzing Numeric variable

# %%
house_train_dataset.hist(figsize= (20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a269600b8>,
# ...
#       dtype=object)

# %%
house_train_dataset.describe(include='all')
# Out:
#                  Id   MSSubClass MSZoning  LotFrontage        LotArea Street  \
# count   1460.000000  1460.000000     1460  1201.000000    1460.000000   1460
# unique          NaN          NaN        5          NaN            NaN      2
# top             NaN          NaN       RL          NaN            NaN   Pave
# freq            NaN          NaN     1151          NaN            NaN   1454
# mean     730.500000    56.897260      NaN    70.049958   10516.828082    NaN
# std      421.610009    42.300571      NaN    24.284752    9981.264932    NaN
# min        1.000000    20.000000      NaN    21.000000    1300.000000    NaN
# 25%      365.750000    20.000000      NaN    59.000000    7553.500000    NaN
# 50%      730.500000    50.000000      NaN    69.000000    9478.500000    NaN
# 75%     1095.250000    70.000000      NaN    80.000000   11601.500000    NaN
# max     1460.000000   190.000000      NaN   313.000000  215245.000000    NaN
#
# ...

# %% [markdown]
# ## Analyzing Categorical Variable

# %%
categorical_variable= ['LotFrontage', 'Alley', 'PoolQC', 'Fence', 'MiscFeature', 'FireplaceQu', 'YrSold', "SaleCondition","Utilities"]

# %%
plt.scatter(house_train_dataset.LotFrontage ,house_train_dataset.SalePrice)
plt.show()

# %%
fig, ax = plt.subplots(2, 4, figsize=(20, 10))
for variable, subplot in zip(categorical_variable, ax.flatten()):
    sns.countplot(house_train_dataset[variable], ax=subplot)
    for label in subplot.get_xticklabels():
        label.set_rotation(90)

# %% [markdown]
# ### Relationship between Independent and Dependent Variables

# %%
fig, ax = plt.subplots(20, 4, figsize=(15, 30))
for variable, subplot in zip(house_train_dataset, ax.flatten()):
    sns.scatterplot(x=house_train_dataset[variable], y=house_train_dataset['SalePrice'], ax=subplot)
    for label in subplot.get_xticklabels():
        label.set_rotation(90)

# %% [markdown]
# Looking at the plots the relationship between the dependent and independent variable looks linear, the dataset can be analyzed further, but I'm quite confident that the relationship is linear and can use linear model.

# %% [markdown]
# ## Missing Values

# %%
#Lets create a heatmap to see which all columns has null values
plt.figure(figsize=(30,12))
sns.heatmap(house_train_dataset.isnull(), yticklabels=False, cmap='viridis',cbar='cyan')

# %%
null_value = house_train_dataset.isnull().sum()
null_value[60:80]
# Out:
# GarageFinish       81
# GarageCars          0
# GarageArea          0
# GarageQual         81
# GarageCond         81
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# PoolArea            0
# PoolQC           1453
# Fence            1179
# MiscFeature      1406
# MiscVal             0
# MoSold              0
# YrSold              0
# SaleType            0
# SaleCondition       0
# dtype: int64

# %% [markdown]
# ### Test set Missing values

# %%
plt.figure(figsize=(30,12))
sns.heatmap(house_test_dataset.isnull(), yticklabels=False, cmap='viridis',cbar='cyan')

# %%
null_value = house_test_dataset.isnull().sum()
null_value[60:80]
# Out:
# GarageFinish       78
# GarageCars          1
# GarageArea          1
# GarageQual         78
# GarageCond         78
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# PoolArea            0
# PoolQC           1456
# Fence            1169
# MiscFeature      1408
# MiscVal             0
# MoSold              0
# YrSold              0
# SaleType            0
# SaleCondition       0
# dtype: int64

# %%
mode= house_train_dataset['SaleType'].mode()
house_test_dataset['SaleType']=house_test_dataset['SaleType'].fillna(mode[0])

# %% [markdown]
# ## Categorical Variable Missing Value

# %% [markdown]
# Variables with more than 50% null values are labeled as other.
#
# variables with less than 50% null values, the null values are replaced with the most frequent value.

# %%
variables= ['Alley', "FireplaceQu","PoolQC","MiscFeature","Fence"]
for feature in variables:
    house_train_dataset[feature]=house_train_dataset[feature].fillna('other')

# %%
other_variables= ['LotFrontage', 'MasVnrType', 'MasVnrArea', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
                  'BsmtFinType2', 'Electrical']

# %%
for feature in other_variables:
    mode= house_train_dataset[feature].mode()
    house_train_dataset[feature]= house_train_dataset[feature].fillna(mode[0])

# %%
#Lets create a heatmap to see which all columns has null values
plt.figure(figsize=(30,12))
sns.heatmap(house_train_dataset.isnull(), yticklabels=False, cmap='viridis',cbar='cyan')

# %% [markdown]
# ## Encoding Categorical Variable

# %%
#encoding:
def encode_label(df, col):
    #encode the categories using average SalePrice for each category to replace label
    cat_dict ={}
    cats = df[col].cat.categories.tolist()
    for cat in cats:
        cat_dict[cat] = house_train_dataset[house_train_dataset[col]] == cat['SalePrice'].mean()  
    df[col] = df[col].map(cat_dict)

# %%
for col in house_train_dataset.columns:
    if house_train_dataset[col].dtype.name == "category":
        encode_label(house_train_dataset, col)

# %%
# Correlations between selected features and response
fig = plt.figure(figsize=(20, 14))
sns.heatmap(house_train_dataset.corr(), cmap='Blues', annot=False)
plt.xticks(rotation=45)
plt.show()
